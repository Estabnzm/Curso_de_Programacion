# %% [markdown]
# <a href="https://colab.research.google.com/github/Estabnzm/Curso_de_Programacion/blob/main/Copia_de_Gestion_de_portafolios_financieros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cliente = ["Juan Perez","Maria Rodriuez","Carlos Lopez","Ana Gomez"]
montos_invertidos = [10000,20000,30000,40000]
rendimientos = [5.5,6.0,4.0,7.5]
print(cliente)
print(montos_invertidos)
print(rendimientos)
# Out:
# ['Juan Perez', 'Maria Rodriuez', 'Carlos Lopez', 'Ana Gomez']
# [10000, 20000, 30000, 40000]
# [5.5, 6.0, 4.0, 7.5]

# %%
cliente_1 = (cliente[0], montos_invertidos[0], rendimientos[0])
cliente_2 = (cliente[1],montos_invertidos[1],rendimientos[1])
cliente_3 = (cliente[2],montos_invertidos[2],rendimientos[2])
cliente_4 = (cliente[3],montos_invertidos[3],rendimientos[3])
print(cliente_1)
print(cliente_1)
print(cliente_2)
print(cliente_3)
print(cliente_4)
# Out:
# ('Juan Perez', 10000, 5.5)
# ('Juan Perez', 10000, 5.5)
# ('Maria Rodriuez', 20000, 6.0)
# ('Carlos Lopez', 30000, 4.0)
# ('Ana Gomez', 40000, 7.5)

# %%
portafolio = {"Juan Perez":{"monto invertido":10000,"rendimiento":5.5},"Maria Rodriuez":{"monto invertido":20000,"rendimiento":6.0},"Carlos Lopez":{"monto invertido":30000,"rendimiento":4.0},"Ana Gomez":{"monto invertido":40000,"rendimiento":7.5}}
print(type(portafolio))
print(portafolio)
# Out:
# <class 'dict'>
# {'Juan Perez': {'monto invertido': 10000, 'rendimiento': 5.5}, 'Maria Rodriuez': {'monto invertido': 20000, 'rendimiento': 6.0}, 'Carlos Lopez': {'monto invertido': 30000, 'rendimiento': 4.0}, 'Ana Gomez': {'monto invertido': 40000, 'rendimiento': 7.5}}

# %%
for cliente, datos in portafolio.items():
  if datos["rendimiento"]>5:
    print(f"{cliente} tiene un rendimiento de {datos['rendimiento']}%")
# Out:
# Juan Perez tiene un rendimiento de 5.5%
# Maria Rodriuez tiene un rendimiento de 6.0%
# Ana Gomez tiene un rendimiento de 7.5%

# %%
rendimiento_total = 0
for cliente, datos in portafolio.items():
  rendimiento_cliente = (datos["monto invertido"]*datos["rendimiento"])/100
  rendimiento_total = rendimiento_total + rendimiento_cliente
print(f"El rendimiento total del portafolio es: ${rendimiento_total:.2f}")
cliente_mayor_rendimiento = 0

for cliente, cliente_data in portafolio.items():
 rendimiento_cliente = (datos["monto invertido"]*datos["rendimiento"])/100
 if rendimiento_cliente > cliente_mayor_rendimiento:
  print(f"El cliente con mayor rendimiento es: {cliente}")
  cliente_mayor_rendimiento = rendimiento_cliente
# Out:
# El rendimiento total del portafolio es: $6950.00
# El cliente con mayor rendimiento es: Juan Perez

# %%
portafolio["Carlos Lopez"]["monto invertido"] += 25000
print(portafolio)
portafolio["Laura Fernandez"] = {"monto invertido": 22000, "rendimiento": 6.8}
print(portafolio)
portafolio["Maria Rodriuez"] = {"monto invertido":20000, "rendimiento": 6.0}
print(portafolio)
# Out:
# {'Juan Perez': {'monto invertido': 10000, 'rendimiento': 5.5}, 'Carlos Lopez': {'monto invertido': 395000, 'rendimiento': 4.0}, 'Laura Fernandez': {'monto invertido': 22000, 'rendimiento': 6.8}, 'Maria Rodriuez': {'monto invertido': 20000, 'rendimiento': 6.0}}
# {'Juan Perez': {'monto invertido': 10000, 'rendimiento': 5.5}, 'Carlos Lopez': {'monto invertido': 395000, 'rendimiento': 4.0}, 'Laura Fernandez': {'monto invertido': 22000, 'rendimiento': 6.8}, 'Maria Rodriuez': {'monto invertido': 20000, 'rendimiento': 6.0}}
# {'Juan Perez': {'monto invertido': 10000, 'rendimiento': 5.5}, 'Carlos Lopez': {'monto invertido': 395000, 'rendimiento': 4.0}, 'Laura Fernandez': {'monto invertido': 22000, 'rendimiento': 6.8}, 'Maria Rodriuez': {'monto invertido': 20000, 'rendimiento': 6.0}}

# %%
portafolio.pop("Ana gomez")
print(portafolio)
