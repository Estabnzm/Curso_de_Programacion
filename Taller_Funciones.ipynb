# %% [markdown]
# <a href="https://colab.research.google.com/github/Estabnzm/Curso_de_Programacion/blob/main/Taller_Funciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Adicionando etiquetas a los alimentos**

# %% [markdown]
# ##**Árbol de calorías**

# %%
banano = {
    "tamano_porcion":28,
    "calorias":94.1,
    "grasa":300,
    "sodio":1.96,
    "azucar":16,
    "fibra":0.504
}

if banano["calorias"] < 5:
    etiqueta_calorias = "SIN CALORÍAS"
elif banano["calorias"] < 40:
    etiqueta_calorias = "BAJO EN CALORÍAS"
else:
    etiqueta_calorias = None

print(etiqueta_calorias)
# Out:
# None

# %% [markdown]
# ###_Ejercicio #1_
# Utlizar el codigo del banano con y sustituir con tomate

# %%
tomate = {
    "tamano_porción":125,
    "calorias":22.5,
    "grasa":250,
    "sodio":6.25,
    "azucar":3.29,
    "fibra":1.5
}
if tomate["calorias"] < 5:
    etiqueta_calorias = "SIN CALORÍAS"
elif tomate["calorias"] < 40:
    etiqueta_calorias = "BAJO EN CALORÍAS"
else:
    etiqueta_calorias = None

print(etiqueta_calorias)
# Out:
# BAJO EN CALORÍAS

# %% [markdown]
# ###_Ejercicio #2_
# Probar la función asignar_etiquetas_calorias() utilizando el banano

# %%
def asignar_etiquetas_calorias(banano):
    if alimento["calorias"] < 5:
        etiqueta_calorias = "SIN CALORÍAS"
    elif alimento["calorias"] < 40:
        etiqueta_calorias = "BAJO EN CALORÍAS"
    else:
        etiqueta_calorias = None
print(etiqueta_calorias)
# Out:
# None

# %% [markdown]
# ###_Ejercicio #3_
# Asignar help(asignar_etiqueta_calorias)

# %%
def asignar_etiqueta_calorias(alimento):
    """
    Asigna una etiqueta de calorías de acuerdo a las reglas de la FDA.

    Argumentos:
    alimento: Un dicccionario Python que tiene al menos una llave "calorías".

    Salida:
    Sin salidas. Esta funcion simplemente imprime la etiqueta.
    """
    if alimento["calorias"] < 5:
        etiqueta_calorias = "SIN CALORÍAS"
    elif alimento["calorias"] < 40:
        etiqueta_calorias = "BAJO EN CALORÍAS"
    else:
        etiqueta_calorias = None
print(etiqueta_calorias)
# Out:
# None

# %% [markdown]
# ###Se añade _help_ a la función anterior

# %%
def help(asignar_etiqueta_calorias):
    """
    Asigna una etiqueta de calorías de acuerdo a las reglas de la FDA.

    Argumentos:
    alimento: Un dicccionario Python que tiene al menos una llave "calorías".

    Salida:
    Sin salidas. Esta funcion simplemente imprime la etiqueta.
    """
    if alimento["calorias"] < 5:
        etiqueta_calorias = "SIN CALORÍAS"
    elif alimento["calorias"] < 40:
        etiqueta_calorias = "BAJO EN CALORÍAS"
    else:
        etiqueta_calorias = None
print(etiqueta_calorias)
# Out:
# None

# %% [markdown]
# ###Se cambia _print_ de la primera función por _return_

# %%
def asignar_etiqueta_calorias(alimento):
    """
    Asigna una etiqueta de calorías de acuerdo a las reglas de la FDA.

    Argumentos:
    alimento: Un dicccionario Python que tiene al menos una llave "calorías".

    Salida:
    Sin salidas. Esta funcion simplemente imprime la etiqueta.
    """
    if alimento["calorias"] < 5:
        etiqueta_calorias = "SIN CALORÍAS"
    elif alimento["calorias"] < 40:
        etiqueta_calorias = "BAJO EN CALORÍAS"
    else:
        etiqueta_calorias = None
    return etiqueta_calorias

# %%
etiqueta_caloria_tomate = asignar_etiqueta_calorias(tomate)
etiqueta_caloria_banano = asignar_etiqueta_calorias(banano)

print("La Etiqueta para tomate es", etiqueta_caloria_tomate)
print("y la Etiqueta para banano es", etiqueta_caloria_banano)
# Out:
# La Etiqueta para tomate es BAJO EN CALORÍAS
# y la Etiqueta para banano es None

# %% [markdown]
# ###_Ejercicio #4_
# Añardir etiquetas del contenido de grasa

# %%
tomate = {
    "tamano_porcion":125,
    "calorias":22.5,
    "grasa":250,
    "sodio":6.25,
    "azucar":3.29,
    "fibra":1.5
}
if tomate["grasa"] < 500:
  etiqueta_grasa = "SIN GRASA"
elif tomate["grasa"] < 300:
  etiqueta_grasa = "BAJA EN GRASA"
else:
  etiqueta_grasa = None

print(etiqueta_grasa)
# Out:
# SIN GRASA

# %% [markdown]
# ## **Ejercicio  #5**
# Modifica la función asignar_etiqueta_grasa() para utilizar gramos en lugar de miligramos en los condicionales.

# %%
tomate = {
    "tamano_porcion":125,
    "calorias":22.5,
    "grasa":0.25,
    "sodio":6.25,
    "azucar":3.29,
    "fibra":1.5
}
if tomate["grasa"] < 0.5:
  etiqueta_grasa = "SIN GRASA"
elif tomate["grasa"] < 0.3:
  etiqueta_grasa = "BAJA EN GRASA"
else:
  etiqueta_grasa = None

print(etiqueta_grasa)
# Out:
# SIN GRASA

# %%
azucar = {
    "tamano_porcion":125,
    "calorias":22.5,
    "grasa":0.25,
    "sodio":6.25,
    "azucar":3.29,
    "fibra":1.5
}

if azucar["azucar"] < 5:
  etiqueta_azucar = "SIN AZÚCAR"

elif azucar["azucar"] >5:
  etiqueta_azucar = " NONE"



print(etiqueta_azucar)
# Out:
# SIN AZÚCAR

# %% [markdown]
# # **Ejercicio 6**
# Piensa en una estrategia para convertir estas tres funciones en una sola, evitando repetir código innecesariamente. No escribas todavía ningún código, sólo escribe la estrategia que seguirías.
#
# # **Solución**
# Utilizaria la función landa para hacer las entredas del diccionario para cada una de las variables separadas de comas, en el proximo genero otras 3 variables con las especifiaciones de cada variable, depués genero las condicionales de cada etiqueta para que me imprima la que le solicite.
